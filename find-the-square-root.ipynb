# %% [markdown]
# ## **Find The Square Root**

# %% [markdown]
# Create a function whose name is ```square_root``` that does the following:
#
# Given a second order polynomial, find the roots (roots should be in real number). The input will be 3 numbers, each of them representing 'a', 'b', and 'c', in ax^2 + bx + c = 0.
#
# Your task is to find the root of ax^2 + bx + c = 0.
#
# However, notice that sometimes an equation cannot be solved, or they have only one solution instead of two. Your function should also take this into consideration.
#
# The input of your function is 3 numbers, first number is the 'a' constant, second number is the 'b' constant, and third number is the 'c' constant.
#
# ##### Example 1:
#
# Input: a = 1, b = -5, c = 6.
#
# This means, the equation is 1x^2 - 5x + 6 = 0.
# This equation has two solutions, the first solution is x = 3, and the second solution is x = 2. So, your output should be:
#
# Output: 'X1 = 3, X2 = 2'.
#
# When we run the code ```square_root(1, -5, 6)``` the output will be: 'X1 = 3, X2 = 2'
#
# ##### Example 2:
#
# Input: a = 2, b = 4, c = 2.
#
# This means, the equation is 2x^2 + 4x + 2 = 0.
# This equation has only one solution, which is x = -1.
#
# Output; 'X = -1'.
#
# ##### Example 3:
#
# Input: a = 1, b = 1, c = 9.
#
# This means, the equation is x^2 + x + 9 = 0.
# This equation has no real solution. (If you have learned about imaginary or complex numbers, the solution of this equation is those kind of numbers. But here, we're just going to deal with real numbers).
#
# Output: 'No solution'.

# %%
import numpy as np

# %%
# create a function whose name is square_root
def square_root(a, b, c):

  # input the value of three constanta of a second order polynomial
  const = [a, b, c]

  # calculate the value of roots using np.roots()
  # x1 is a variable that define the value of first solution and x2 is a variable that define the value of second solution
  x1 = np.roots(const)[0]
  x2 = np.roots(const)[1]

  # using this 'if' to define the first condition when the value of x1 is not equal to the value of x2, there will be 2 solutions 
  if x1 != x2 :
    # using this 'if' to define the second condition when the value of x1 and x2 are real number, the solution will be print
    if np.isreal(x1) and np.isreal(x2) :
      print('X1 =' ,round(x1),', X2 =' , round(x2))
    # using this 'else' statement to define the condition when the value of x1 and x2 are not real number (imaginary or complex number), there is no solution 
    else :
      print('No Solution')
  # using this 'else' statement to define the condition when value of x1 is equal to value of x2 , there will be 1 solution 
  else :
    print('X =', round(x1))

# %%
square_root(1, -5, 6)
# Out:
# X1 = 3 , X2 = 2

# %%
square_root(2, 4, 2)
# Out:
# X = -1

# %%
square_root(1, 1, 9)
# Out:
# No Solution
